# %%
from keras.applications.resnet50 import ResNet50, decode_predictions
from keras.preprocessing import image
import numpy as np

import requests
from io import BytesIO
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %% [markdown]
# ![](https://scontent-waw1-1.cdninstagram.com/vp/a680fcaf7d4bfab99799b047c334156f/5D330637/t51.2885-15/e35/50858231_558479341292557_8870325505610651813_n.jpg?_nc_ht=scontent-waw1-1.cdninstagram.com)

# %%
url_img = 'https://kochamwroclaw.pl/wp-content/uploads/12ec4c8478d2d658d94da5fe27c68d89.jpg'

response = requests.get(url_img)
img = Image.open(BytesIO(response.content))
img = img.resize( (224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F1371BAD30>

# %% [markdown]
# ![]('https://static.maxmodels.pl/photos/0/4/1b/041bfb71714425e1b8d734d6fc446a97_483380.jpg')

# %%
X =image.img_to_array(img)
X = np.expand_dims(X, axis=0)
X.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(X)

# %%
decode_predictions(y_pred)
# Out:
# [[('n02930766', 'cab', 0.46718597),
#   ('n04296562', 'stage', 0.050348848),
#   ('n04335435', 'streetcar', 0.04896534),
#   ('n02965783', 'car_mirror', 0.0373525),
#   ('n03388043', 'fountain', 0.02749272)]]

# %%
img2 = Image.open('data/photo1.jpg')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=597x490 at 0x1F1371CA390>

# %%
img2 = img2.resize( (224, 224))
X = image.img_to_array(img2)
X = np.expand_dims(X, axis=0)
y_pred = model.predict(X)
decode_predictions(y_pred)
# Out:
# [[('n03843555', 'oil_filter', 0.27214563),
#   ('n04069434', 'reflex_camera', 0.09363084),
#   ('n04009552', 'projector', 0.072393514),
#   ('n04074963', 'remote_control', 0.045682408),
#   ('n02979186', 'cassette_player', 0.037706017)]]

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1F12F525E48>
